# %%
import sys

sys.path.append("../../src/stong_core_cython")
sys.path.append("../../")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import unrestricted_hartree_fock
import restricted_hartree_fock
import basis_data
import importlib
import matrix
from scipy.constants import physical_constants
from scipy.optimize import minimize
from scipy.linalg import eigh

importlib.reload(restricted_hartree_fock)
importlib.reload(unrestricted_hartree_fock)
importlib.reload(basis_data)
importlib.reload(matrix)

from atom import *
from unrestricted_hartree_fock import *
from basis_data import *
from matrix import *
from restricted_hartree_fock import *

# %%
df = pd.read_csv("../make_base/sto_ng/sto_3g.csv")

# %% [markdown]
# H2のエネルギーの結合長依存性

# %%
def solve_H(zetas):
    atoms = [Atom("H", np.array([0.0, 0.0, 0.0]))]
    molecule = Molecule(atoms)
    basis_data = {"H": create_basis_data(df, zetas, 1, 0)}
    hartreefock = UnrestrictedHartreeFock(
        molecule, basis_data, max_iter=10000, tol=1e-10
    )
    hartreefock.scf()
    hartreefock.calculate_total_energy()
    results = hartreefock.get_results()
    return results, hartreefock


def solve_rhf(r, zetas):
    atoms = [Atom("H", np.array([0.0, 0.0, 0.0])), Atom("H", np.array([r, 0.0, 0.0]))]
    molecule = Molecule(atoms)
    basis_data = {"H": create_basis_data(df, zetas, 1, 0)}
    hartreefock = RestrictedHartreeFock(molecule, basis_data, max_iter=10000, tol=1e-10)
    hartreefock.scf()
    hartreefock.calculate_total_energy()
    results = hartreefock.get_results()
    return results, hartreefock


def solve_uhf(r, zetas, P_up=None, P_dn=None):
    atoms = [Atom("H", np.array([0.0, 0.0, 0.0])), Atom("H", np.array([r, 0.0, 0.0]))]
    molecule = Molecule(atoms)
    basis_data = {"H": create_basis_data(df, zetas, 1, 0)}
    hartreefock = UnrestrictedHartreeFock(
        molecule, basis_data, max_iter=10000, tol=1e-10
    )
    if P_up is not None:
        hartreefock.P_up = P_up
        hartreefock.P_dn = P_dn
    hartreefock.scf()
    hartreefock.calculate_total_energy()
    results = hartreefock.get_results()
    return results, hartreefock


def get_energy(r, zetas):
    results, _ = solve_uhf(r, zetas)
    return results["energy"] + 1 / r


def solve_rhf_ci(r, results, hartreefock):
    vec = results["vec"]
    ERI = hartreefock.ERI
    T = hartreefock.T
    V = hartreefock.V
    num_orb = 2
    ci_matrix = np.zeros((num_orb, num_orb))
    ci_matrix[0, 0] += 2 * np.einsum("ij, i,j", T, vec[:, 0], vec[:, 0])
    ci_matrix[0, 0] += 2 * np.einsum("ij, i,j", V, vec[:, 0], vec[:, 0])
    ci_matrix[0, 0] += np.einsum(
        "ijkl,i, j, k,l", ERI, vec[:, 0], vec[:, 0], vec[:, 0], vec[:, 0]
    )
    ci_matrix[1, 1] += 2 * np.einsum("ij, i,j", T, vec[:, 1], vec[:, 1])
    ci_matrix[1, 1] += 2 * np.einsum("ij, i,j", V, vec[:, 1], vec[:, 1])
    ci_matrix[1, 1] += np.einsum(
        "ijkl,i, j, k,l", ERI, vec[:, 1], vec[:, 1], vec[:, 1], vec[:, 1]
    )
    ci_matrix[0, 1] += np.einsum(
        "ijkl,i, j, k,l", ERI, vec[:, 0], vec[:, 1], vec[:, 0], vec[:, 1]
    )
    ci_matrix[1, 0] += np.einsum(
        "ijkl,i, j, k,l", ERI, vec[:, 1], vec[:, 0], vec[:, 1], vec[:, 0]
    )
    val, vec = eigh(ci_matrix)
    return val[0] + 1 / r

# %%
df_zetas["H"] = pd.DataFrame([1.24])

# %%
res, hartree_fock = solve_H([1.24])
# Out:
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.])])

# %%
rs = np.linspace(0.5, 6.0, 100)
es_uhf = []
es_ci = []
for i, r in enumerate(reversed(rs)):
    print(i)
    if i == 0:
        results, hartree_fock = solve_uhf(r, df_zetas["H"])
    else:
        results, hartree_fock = solve_uhf(r, df_zetas["H"], P_up=P_up, P_dn=P_dn)
    P_up = results["P_up"]
    P_dn = results["P_dn"]
    es_uhf.insert(0, results["energy"] + 1 / r)
    # es_ci.insert(0, solve_uhf_ci(r, results, hartree_fock))
# Out:
# 0
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[6. 0. 0.])])
# 1
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.94444444 0.         0.        ])])
# 2
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.88888889 0.         0.        ])])
# 3
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.83333333 0.         0.        ])])
# 4
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.77777778 0.         0.        ])])
# 5
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.72222222 0.         0.        ])])
# 6
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.66666667 0.         0.        ])])
# 7
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.61111111 0.         0.        ])])
# 8
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.55555556 0.         0.        ])])
# 9
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.5 0.  0. ])])
# 10
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.44444444 0.         0.        ])])
# 11
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.38888889 0.         0.        ])])
# 12
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.33333333 0.         0.        ])])
# 13
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.27777778 0.         0.        ])])
# 14
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.22222222 0.         0.        ])])
# 15
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.16666667 0.         0.        ])])
# 16
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.11111111 0.         0.        ])])
# 17
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.05555556 0.         0.        ])])
# 18
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5. 0. 0.])])
# 19
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.94444444 0.         0.        ])])
# 20
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.88888889 0.         0.        ])])
# 21
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.83333333 0.         0.        ])])
# 22
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.77777778 0.         0.        ])])
# 23
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.72222222 0.         0.        ])])
# 24
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.66666667 0.         0.        ])])
# 25
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.61111111 0.         0.        ])])
# 26
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.55555556 0.         0.        ])])
# 27
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.5 0.  0. ])])
# 28
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.44444444 0.         0.        ])])
# 29
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.38888889 0.         0.        ])])
# 30
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.33333333 0.         0.        ])])
# 31
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.27777778 0.         0.        ])])
# 32
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.22222222 0.         0.        ])])
# 33
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.16666667 0.         0.        ])])
# 34
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.11111111 0.         0.        ])])
# 35
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.05555556 0.         0.        ])])
# 36
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4. 0. 0.])])
# 37
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.94444444 0.         0.        ])])
# 38
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.88888889 0.         0.        ])])
# 39
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.83333333 0.         0.        ])])
# 40
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.77777778 0.         0.        ])])
# 41
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.72222222 0.         0.        ])])
# 42
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.66666667 0.         0.        ])])
# 43
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.61111111 0.         0.        ])])
# 44
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.55555556 0.         0.        ])])
# 45
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.5 0.  0. ])])
# 46
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.44444444 0.         0.        ])])
# 47
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.38888889 0.         0.        ])])
# 48
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.33333333 0.         0.        ])])
# 49
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.27777778 0.         0.        ])])
# 50
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.22222222 0.         0.        ])])
# 51
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.16666667 0.         0.        ])])
# 52
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.11111111 0.         0.        ])])
# 53
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.05555556 0.         0.        ])])
# 54
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3. 0. 0.])])
# 55
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.94444444 0.         0.        ])])
# 56
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.88888889 0.         0.        ])])
# 57
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.83333333 0.         0.        ])])
# 58
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.77777778 0.         0.        ])])
# 59
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.72222222 0.         0.        ])])
# 60
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.66666667 0.         0.        ])])
# 61
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.61111111 0.         0.        ])])
# 62
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.55555556 0.         0.        ])])
# 63
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.5 0.  0. ])])
# 64
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.44444444 0.         0.        ])])
# 65
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.38888889 0.         0.        ])])
# 66
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.33333333 0.         0.        ])])
# 67
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.27777778 0.         0.        ])])
# 68
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.22222222 0.         0.        ])])
# 69
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.16666667 0.         0.        ])])
# 70
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.11111111 0.         0.        ])])
# 71
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.05555556 0.         0.        ])])
# 72
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2. 0. 0.])])
# 73
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.94444444 0.         0.        ])])
# 74
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.88888889 0.         0.        ])])
# 75
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.83333333 0.         0.        ])])
# 76
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.77777778 0.         0.        ])])
# 77
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.72222222 0.         0.        ])])
# 78
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.66666667 0.         0.        ])])
# 79
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.61111111 0.         0.        ])])
# 80
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.55555556 0.         0.        ])])
# 81
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.5 0.  0. ])])
# 82
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.44444444 0.         0.        ])])
# 83
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.38888889 0.         0.        ])])
# 84
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.33333333 0.         0.        ])])
# 85
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.27777778 0.         0.        ])])
# 86
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.22222222 0.         0.        ])])
# 87
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.16666667 0.         0.        ])])
# 88
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.11111111 0.         0.        ])])
# 89
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.05555556 0.         0.        ])])
# 90
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1. 0. 0.])])
# 91
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.94444444 0.         0.        ])])
# 92
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.88888889 0.         0.        ])])
# 93
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.83333333 0.         0.        ])])
# 94
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.77777778 0.         0.        ])])
# 95
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.72222222 0.         0.        ])])
# 96
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.66666667 0.         0.        ])])
# 97
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.61111111 0.         0.        ])])
# 98
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.55555556 0.         0.        ])])
# 99
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.5 0.  0. ])])

# %%
es_rhf = []
# es_ci = []
for i, r in enumerate(reversed(rs)):
    print(i)
    results, hartree_fock = solve_rhf(r, df_zetas["H"])
    es_rhf.insert(0, results["energy"] + 1 / r)
    es_ci.insert(0, solve_rhf_ci(r, results, hartree_fock))
# Out:
# 0
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[6. 0. 0.])])
# 1
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.94444444 0.         0.        ])])
# 2
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.88888889 0.         0.        ])])
# 3
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.83333333 0.         0.        ])])
# 4
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.77777778 0.         0.        ])])
# 5
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.72222222 0.         0.        ])])
# 6
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.66666667 0.         0.        ])])
# 7
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.61111111 0.         0.        ])])
# 8
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.55555556 0.         0.        ])])
# 9
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.5 0.  0. ])])
# 10
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.44444444 0.         0.        ])])
# 11
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.38888889 0.         0.        ])])
# 12
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.33333333 0.         0.        ])])
# 13
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.27777778 0.         0.        ])])
# 14
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.22222222 0.         0.        ])])
# 15
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.16666667 0.         0.        ])])
# 16
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.11111111 0.         0.        ])])
# 17
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5.05555556 0.         0.        ])])
# 18
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[5. 0. 0.])])
# 19
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.94444444 0.         0.        ])])
# 20
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.88888889 0.         0.        ])])
# 21
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.83333333 0.         0.        ])])
# 22
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.77777778 0.         0.        ])])
# 23
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.72222222 0.         0.        ])])
# 24
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.66666667 0.         0.        ])])
# 25
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.61111111 0.         0.        ])])
# 26
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.55555556 0.         0.        ])])
# 27
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.5 0.  0. ])])
# 28
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.44444444 0.         0.        ])])
# 29
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.38888889 0.         0.        ])])
# 30
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.33333333 0.         0.        ])])
# 31
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.27777778 0.         0.        ])])
# 32
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.22222222 0.         0.        ])])
# 33
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.16666667 0.         0.        ])])
# 34
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.11111111 0.         0.        ])])
# 35
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4.05555556 0.         0.        ])])
# 36
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[4. 0. 0.])])
# 37
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.94444444 0.         0.        ])])
# 38
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.88888889 0.         0.        ])])
# 39
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.83333333 0.         0.        ])])
# 40
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.77777778 0.         0.        ])])
# 41
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.72222222 0.         0.        ])])
# 42
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.66666667 0.         0.        ])])
# 43
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.61111111 0.         0.        ])])
# 44
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.55555556 0.         0.        ])])
# 45
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.5 0.  0. ])])
# 46
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.44444444 0.         0.        ])])
# 47
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.38888889 0.         0.        ])])
# 48
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.33333333 0.         0.        ])])
# 49
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.27777778 0.         0.        ])])
# 50
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.22222222 0.         0.        ])])
# 51
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.16666667 0.         0.        ])])
# 52
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.11111111 0.         0.        ])])
# 53
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3.05555556 0.         0.        ])])
# 54
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[3. 0. 0.])])
# 55
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.94444444 0.         0.        ])])
# 56
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.88888889 0.         0.        ])])
# 57
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.83333333 0.         0.        ])])
# 58
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.77777778 0.         0.        ])])
# 59
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.72222222 0.         0.        ])])
# 60
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.66666667 0.         0.        ])])
# 61
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.61111111 0.         0.        ])])
# 62
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.55555556 0.         0.        ])])
# 63
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.5 0.  0. ])])
# 64
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.44444444 0.         0.        ])])
# 65
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.38888889 0.         0.        ])])
# 66
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.33333333 0.         0.        ])])
# 67
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.27777778 0.         0.        ])])
# 68
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.22222222 0.         0.        ])])
# 69
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.16666667 0.         0.        ])])
# 70
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.11111111 0.         0.        ])])
# 71
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2.05555556 0.         0.        ])])
# 72
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[2. 0. 0.])])
# 73
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.94444444 0.         0.        ])])
# 74
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.88888889 0.         0.        ])])
# 75
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.83333333 0.         0.        ])])
# 76
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.77777778 0.         0.        ])])
# 77
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.72222222 0.         0.        ])])
# 78
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.66666667 0.         0.        ])])
# 79
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.61111111 0.         0.        ])])
# 80
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.55555556 0.         0.        ])])
# 81
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.5 0.  0. ])])
# 82
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.44444444 0.         0.        ])])
# 83
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.38888889 0.         0.        ])])
# 84
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.33333333 0.         0.        ])])
# 85
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.27777778 0.         0.        ])])
# 86
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.22222222 0.         0.        ])])
# 87
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.16666667 0.         0.        ])])
# 88
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.11111111 0.         0.        ])])
# 89
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.05555556 0.         0.        ])])
# 90
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1. 0. 0.])])
# 91
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.94444444 0.         0.        ])])
# 92
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.88888889 0.         0.        ])])
# 93
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.83333333 0.         0.        ])])
# 94
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.77777778 0.         0.        ])])
# 95
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.72222222 0.         0.        ])])
# 96
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.66666667 0.         0.        ])])
# 97
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.61111111 0.         0.        ])])
# 98
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.55555556 0.         0.        ])])
# 99
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[0.5 0.  0. ])])

# %%
fig, ax = plt.subplots()
ax.plot(rs, es_rhf - 2 * res["energy"], label="RHF")
ax.plot(rs, es_uhf - 2 * res["energy"], label="UHF")
ax.plot(rs, es_ci - 2 * res["energy"], label="CI")
ax.legend()
ax.axhline(0, color="black", lw=0.5)
# ax.set_ylim(
#    -0.2,
# )
# ax.set_xlim([0.5, 3.4])
plt.show()
fig.savefig("hf_ci.pdf")

# %%
results, hartree_fock = solve_rhf(1.4, [1.24])
energy_rhf = results["energy"] + 1 / 1.4
energy_ci = solve_rhf_ci(1.4, results, hartree_fock)
print(energy_ci - energy_rhf)
# Out:
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.]), Atom(symbol=H, atomic_number=1, position=[1.4 0.  0. ])])
# -0.02056471477881372

# %%
print(energy_ci)
# Out:
# -1.1372904679444567
