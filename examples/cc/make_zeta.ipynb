# %%
import sys

sys.path.append("../../src/stong_core_cython")
sys.path.append("../../")

# %%
import numpy as np
import pandas as pd
import unrestricted_hartree_fock
import basis_data
import importlib
import concurrent.futures
from scipy.optimize import minimize

importlib.reload(unrestricted_hartree_fock)
importlib.reload(basis_data)

from atom import *
from unrestricted_hartree_fock import *
from basis_data import *

# %%
df = pd.read_csv("../make_base/sto_ng/sto_3g.csv")

# %%
def solve(zetas, atom_symbol):
    atoms = [Atom(atom_symbol, np.array([0.0, 0.0, 0.0]))]
    molecule = Molecule(atoms)
    basis_data = {atom_symbol: create_basis_data(df, zetas, 1, 0)}
    hartreefock = UnrestrictedHartreeFock(
        molecule, basis_data, max_iter=10000, tol=1e-10
    )
    hartreefock.scf()
    hartreefock.calculate_total_energy()
    results = hartreefock.get_results()
    return results, hartreefock


def get_energy(zetas, atom_symbol):
    results, _ = solve(zetas, atom_symbol)
    return results["energy"]

# %%
elements = [
    "H",
    "He",
    #    "Li",
    #    "Be",
    #    "B",
    #    "C",
    #    "N",
    #    "O",
    #    "F",
    #    "Ne",
    #    "Na",
    #    "Mg",
    #    "Al",
    #    "Si",
    #    "P",
    #    "S",
    #    "Cl",
    #    "Ar",
    #    "K",
    #    "Ca",
]
# elements = ["H"]
zetas = {}
results = {}
for i, element in enumerate(elements):
    print(element)
    if i == 0:
        result = minimize(
            get_energy,
            [
                1.2372711236608722,
            ],
            args=(element),
        )
    else:
        result = minimize(
            get_energy,
            result.x,
            args=(element),
            bounds=[(0, None)],
        )
    # result = minimize(get_energy, [2.69, 0.75, 0.3], args=(element))
    results[element] = result
    zetas[element] = result.x
    print(zetas[element])
    df_zetas = pd.DataFrame(zetas)
    df_zetas.to_csv("zetas.csv", index=False)
# Out:
# H
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.])])
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.])])
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.])])
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.])])
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.])])
# Start SCF for Molecule(atoms=[Atom(symbol=H, atomic_number=1, position=[0. 0. 0.])])
# [1.00022797]
# He
# Start SCF for Molecule(atoms=[Atom(symbol=He, atomic_number=2, position=[0. 0. 0.])])
# Start SCF for Molecule(atoms=[Atom(symbol=He, atomic_number=2, position=[0. 0. 0.])])
# Start SCF for Molecule(atoms=[Atom(symbol=He, atomic_number=2, position=[0. 0. 0.])])
# Start SCF for Molecule(atoms=[Atom(symbol=He, atomic_number=2, position=[0. 0. 0.])])
# Start SCF for Molecule(atoms=[Atom(symbol=He, atomic_number=2, position=[0. 0. 0.])])
# Start SCF for Molecule(atoms=[Atom(symbol=He, atomic_number=2, position=[0. 0. 0.])])
# [1.68470853]

# %%
results
# Out:
# {'H':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -0.4966449228307716
#          x: [ 1.348e+00  1.182e+00]
#        nit: 20
#        jac: [-1.602e-07  2.235e-08]
#   hess_inv: [[ 5.378e+01  1.984e+01]
#              [ 1.984e+01  1.442e+01]]
#       nfev: 126
#       njev: 42,
#  'He':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -2.839936765851108
#          x: [ 2.411e+00  1.777e+00]
#        nit: 11
#        jac: [-5.990e-06  7.182e-06]
#   hess_inv: [[ 1.745e+01  1.014e+01]
#              [ 1.014e+01  8.428e+00]]
#       nfev: 36
#       njev: 12,
#  'Li':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -7.329116402841278
#          x: [ 2.692e+00  6.523e-01]
#        nit: 4
#        jac: [ 5.960e-06  1.788e-06]
#   hess_inv: [[ 5.535e-01 -8.695e-03]
#              [-8.695e-03  8.979e-01]]
#       nfev: 18
#       njev: 6,
#  'Be':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -14.393642763474203
#          x: [ 3.692e+00  9.704e-01]
#        nit: 4
#        jac: [-2.503e-06  3.576e-06]
#   hess_inv: [[ 5.266e-01 -1.621e-02]
#              [-1.621e-02  4.194e-01]]
#       nfev: 18
#       njev: 6,
#  'B':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -24.2336952564439
#          x: [ 4.692e+00  1.280e+00]
#        nit: 5
#        jac: [-1.192e-06  4.768e-07]
#   hess_inv: [[ 5.284e-01 -1.229e-02]
#              [-1.229e-02  2.950e-01]]
#       nfev: 21
#       njev: 7,
#  'C':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -37.19780270994353
#          x: [ 5.692e+00  1.597e+00]
#        nit: 6
#        jac: [-9.537e-07 -1.431e-06]
#   hess_inv: [[ 5.384e-01 -1.502e-02]
#              [-1.502e-02  2.271e-01]]
#       nfev: 24
#       njev: 8,
#  'N':   message: Desired error not necessarily achieved due to precision loss.
#    success: False
#     status: 2
#        fun: -53.641962993926384
#          x: [ 6.691e+00  1.922e+00]
#        nit: 12
#        jac: [ 8.378e-04  3.738e-04]
#   hess_inv: [[ 6.402e-06 -6.887e-06]
#              [-6.887e-06  7.408e-06]]
#       nfev: 248
#       njev: 79,
#  'O':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -73.76058448085081
#          x: [ 7.689e+00  2.240e+00]
#        nit: 6
#        jac: [-5.722e-06 -4.768e-06]
#   hess_inv: [[ 5.365e-01 -1.253e-02]
#              [-1.253e-02  1.572e-01]]
#       nfev: 21
#       njev: 7,
#  'F':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -97.99100586131436
#          x: [ 8.687e+00  2.562e+00]
#        nit: 7
#        jac: [ 0.000e+00 -1.907e-06]
#   hess_inv: [[ 5.428e-01 -8.666e-03]
#              [-8.666e-03  1.383e-01]]
#       nfev: 24
#       njev: 8,
#  'Ne':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -126.60862021024491
#          x: [ 9.685e+00  2.886e+00]
#        nit: 8
#        jac: [-9.537e-07  3.815e-06]
#   hess_inv: [[ 5.421e-01 -1.338e-02]
#              [-1.338e-02  1.203e-01]]
#       nfev: 27
#       njev: 9,
#  'Na':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -159.48169219175043
#          x: [ 1.068e+01  3.372e+00]
#        nit: 6
#        jac: [-1.907e-06  0.000e+00]
#   hess_inv: [[ 5.471e-01 -1.306e-02]
#              [-1.306e-02  1.199e-01]]
#       nfev: 21
#       njev: 7,
#  'Mg':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -196.3267385979334
#          x: [ 1.167e+01  3.857e+00]
#        nit: 6
#        jac: [ 7.629e-06 -3.815e-06]
#   hess_inv: [[ 5.520e-01 -1.478e-02]
#              [-1.478e-02  1.198e-01]]
#       nfev: 21
#       njev: 7,
#  'Al':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -237.14069774297133
#          x: [ 1.266e+01  4.340e+00]
#        nit: 7
#        jac: [-3.815e-06 -1.907e-06]
#   hess_inv: [[ 6.273e-01  8.547e-03]
#              [ 8.547e-03  9.969e-02]]
#       nfev: 27
#       njev: 9,
#  'Si':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -281.9214909256601
#          x: [ 1.365e+01  4.823e+00]
#        nit: 6
#        jac: [ 7.629e-06  3.815e-06]
#   hess_inv: [[ 5.736e-01 -2.085e-02]
#              [-2.085e-02  1.191e-01]]
#       nfev: 21
#       njev: 7,
#  'P':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -330.6676580524436
#          x: [ 1.464e+01  5.305e+00]
#        nit: 5
#        jac: [-7.629e-06 -7.629e-06]
#   hess_inv: [[ 5.819e-01 -2.597e-02]
#              [-2.597e-02  1.223e-01]]
#       nfev: 18
#       njev: 6,
#  'S':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -383.3781441022223
#          x: [ 1.563e+01  5.786e+00]
#        nit: 5
#        jac: [ 3.815e-06 -3.815e-06]
#   hess_inv: [[ 5.861e-01 -2.691e-02]
#              [-2.691e-02  1.221e-01]]
#       nfev: 18
#       njev: 6,
#  'Cl':   message: Desired error not necessarily achieved due to precision loss.
#    success: False
#     status: 2
#        fun: -440.05216819566124
#          x: [ 1.661e+01  6.267e+00]
#        nit: 5
#        jac: [ 7.629e-06  1.144e-05]
#   hess_inv: [[ 6.413e-01 -3.529e-02]
#              [-3.529e-02  1.136e-01]]
#       nfev: 132
#       njev: 40,
#  'Ar':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -500.6891402585487
#          x: [ 1.760e+01  6.748e+00]
#        nit: 7
#        jac: [ 0.000e+00 -7.629e-06]
#   hess_inv: [[ 4.226e-01  2.800e-02]
#              [ 2.800e-02  1.076e-01]]
#       nfev: 24
#       njev: 8,
#  'K':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -565.2886062707889
#          x: [ 1.859e+01  7.229e+00]
#        nit: 7
#        jac: [ 0.000e+00  7.629e-06]
#   hess_inv: [[ 4.894e-01  2.258e-01]
#              [ 2.258e-01  2.003e-01]]
#       nfev: 33
#       njev: 11,
#  'Ca':   message: Optimization terminated successfully.
#    success: True
#     status: 0
#        fun: -633.8502112995417
#          x: [ 1.958e+01  7.709e+00]
#        nit: 8
#        jac: [ 7.629e-06  7.629e-06]
#   hess_inv: [[ 5.413e-02  7.774e-02]
#              [ 7.774e-02  2.429e-01]]
#       nfev: 45
#       njev: 15}
